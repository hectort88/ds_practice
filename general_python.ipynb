# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('./data/lsd_math_score_data.csv')

# %%
print(type(data))
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
only_math_scores = data['Avg_Math_Test_Score']
print(type(only_math_scores))
only_math_scores
# Out:
# <class 'pandas.core.series.Series'>
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: Avg_Math_Test_Score, dtype: float64

# %%
# Add Column
data['new_column'] = 'Default value'
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score     new_column
# 0                      5     1.17                78.93  Default value
# 1                     15     2.97                58.20  Default value
# 2                     30     3.26                67.47  Default value
# 3                     60     4.69                37.47  Default value
# 4                    120     5.83                45.65  Default value
# 5                    240     6.00                32.92  Default value
# 6                    480     6.41                29.97  Default value

# %%
data['high_score'] = 100 + data['Avg_Math_Test_Score']
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score     new_column  \
# 0                      5     1.17                78.93  Default value
# 1                     15     2.97                58.20  Default value
# 2                     30     3.26                67.47  Default value
# 3                     60     4.69                37.47  Default value
# 4                    120     5.83                45.65  Default value
# 5                    240     6.00                32.92  Default value
# 6                    480     6.41                29.97  Default value
#
#    high_score
# 0      178.93
# 1      158.20
# 2      167.47
# 3      137.47
# 4      145.65
# 5      132.92
# 6      129.97

# %%
clean_data = data[['LSD_ppm', 'Avg_Math_Test_Score']]
clean_data
# Out:
#    LSD_ppm  Avg_Math_Test_Score
# 0     1.17                78.93
# 1     2.97                58.20
# 2     3.26                67.47
# 3     4.69                37.47
# 4     5.83                45.65
# 5     6.00                32.92
# 6     6.41                29.97

# %%
# Dataframe from one column
y = data[['Avg_Math_Test_Score']]
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
# Add Column
data['test_subject'] = "Jennifer Lopez"
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score     new_column  \
# 0                      5     1.17                78.93  Default value
# 1                     15     2.97                58.20  Default value
# 2                     30     3.26                67.47  Default value
# 3                     60     4.69                37.47  Default value
# 4                    120     5.83                45.65  Default value
# 5                    240     6.00                32.92  Default value
# 6                    480     6.41                29.97  Default value
#
#    high_score    test_subject
# 0      178.93  Jennifer Lopez
# 1      158.20  Jennifer Lopez
# 2      167.47  Jennifer Lopez
# 3      137.47  Jennifer Lopez
# 4      145.65  Jennifer Lopez
# 5      132.92  Jennifer Lopez
# 6      129.97  Jennifer Lopez

# %%
# Delete Column
del data['test_subject']
data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score     new_column  \
# 0                      5     1.17                78.93  Default value
# 1                     15     2.97                58.20  Default value
# 2                     30     3.26                67.47  Default value
# 3                     60     4.69                37.47  Default value
# 4                    120     5.83                45.65  Default value
# 5                    240     6.00                32.92  Default value
# 6                    480     6.41                29.97  Default value
#
#    high_score
# 0      178.93
# 1      158.20
# 2      167.47
# 3      137.47
# 4      145.65
# 5      132.92
# 6      129.97

# %%
import life
print(life.the_answer)
print(type(life))
# Out:
# 42
# <class 'module'>

# %%
time = data['Time_Delay_in_Minutes']
lsd_ppm = data['LSD_ppm']
avg_score = data['Avg_Math_Test_Score']

# %%
plt.style.use('ggplot')

plt.plot(time, lsd_ppm, color='r', linewidth=2)
plt.title("Time by Tissue")
plt.xlabel("Time")
plt.ylabel("LSD_ppm")
plt.xlim(0, 500)
plt.ylim(1, 7)
plt.show()

# %%
# We need to use Dataframes
time = data[['Time_Delay_in_Minutes']]
lsd_ppm = data[['LSD_ppm']]
avg_score = data[['Avg_Math_Test_Score']]

from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(lsd_ppm, avg_score)
print(reg.coef_)
print(reg.intercept_)
print(reg.score(lsd_ppm, avg_score))
predicted_score = reg.predict(lsd_ppm)
print(predicted_score)
# Out:
# [[-9.00946642]]
# [89.12387377]
# 0.8778349707775888
# [[78.58279806]
#  [62.36575851]
#  [59.75301325]
#  [46.86947628]
#  [36.59868457]
#  [35.06707528]
#  [31.37319405]]

# %%
plt.scatter(lsd_ppm, avg_score, color='b', alpha=0.7, s=100)
plt.ylabel('AVG Score')
plt.plot(lsd_ppm, predicted_score, linewidth=2)
plt.xlabel('LSD ppm')
plt.show()
